# %% [markdown]
# <a href="https://colab.research.google.com/github/heisenberg0123/Handwritten_Digit_Classification_DL/blob/main/Handwritten_Digit_Classification_DL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing the dependecies

# %%
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns
import cv2
from google.colab.patches import cv2_imshow
from PIL import Image
import tensorflow as tf
tf.random.set_seed(3)
from tensorflow import keras
from keras.datasets import mnist
from tensorflow.math import confusion_matrix

# %%
(X_train,Y_train),(X_test,Y_test) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
df=mnist.load_data()
df.count
# Out:
# <function tuple.count(value, /)>

# %%
type(X_train)
# Out:
# numpy.ndarray

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %%
print(Y_train.shape,Y_test.shape)
# Out:
# (60000,) (10000,)

# %%
plt.imshow(X_train[25])
plt.show()

print(Y_train[25])
# Out:
# 2

# %% [markdown]
# create the model

# %%
model=keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(50,activation='relu'),
     keras.layers.Dense(50,activation='relu'),
    keras.layers.Dense(10,activation='sigmoid')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# compiling

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# training the model

# %%
X_train=X_train/255
X_test=X_test/255

# %%
model.fit(X_train,Y_train,epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.6993 - loss: 4.4238
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8950 - loss: 0.4101
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9204 - loss: 0.3095
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9274 - loss: 0.2933
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9316 - loss: 0.2595
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9373 - loss: 0.2307
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9432 - loss: 0.2076
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9475 - loss: 0.1902
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - accuracy: 0.9513 - loss: 0.1781
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9528 - loss: 0.1675

# %%
loss,accuracy=model.evaluate(X_test,Y_test)
print(accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step - accuracy: 0.9396 - loss: 0.2321
# 0.945900022983551

# %%
Y_pred=model.predict(X_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step

# %%
print(Y_pred.shape)
print(Y_pred[0])
# Out:
# (10000, 10)
# [3.9214212e-02 8.2301022e-04 1.2199516e-01 5.9405923e-01 4.2691350e-01
#  1.2054029e-02 7.9115249e-05 9.9946541e-01 4.0489165e-04 4.8862258e-01]

# %%
label_first_image=np.argmax(Y_pred[0])
print(label_first_image)
# Out:
# 7

# %%
plt.imshow(X_test[0])
plt.show()

# %%
print(Y_test[0])
# Out:
# 7

# %%
print(label_first_image)
# Out:
# 7

# %%
Y_pred_labels=[np.argmax(i) for i in Y_pred]

# %%
print(Y_pred_labels)
# Out:
# [np.int64(7), np.int64(2), np.int64(1), np.int64(0), np.int64(4), np.int64(1), np.int64(4), np.int64(9), np.int64(4), np.int64(9), np.int64(0), np.int64(0), np.int64(9), np.int64(0), np.int64(1), np.int64(5), np.int64(9), np.int64(7), np.int64(3), np.int64(4), np.int64(9), np.int64(6), np.int64(0), np.int64(5), np.int64(4), np.int64(0), np.int64(7), np.int64(4), np.int64(0), np.int64(1), np.int64(3), np.int64(1), np.int64(3), np.int64(4), np.int64(7), np.int64(2), np.int64(7), np.int64(1), np.int64(3), np.int64(1), np.int64(1), np.int64(7), np.int64(4), np.int64(2), np.int64(3), np.int64(5), np.int64(1), np.int64(2), np.int64(4), np.int64(4), np.int64(6), np.int64(3), np.int64(5), np.int64(5), np.int64(0), np.int64(0), np.int64(4), np.int64(1), np.int64(9), np.int64(5), np.int64(7), np.int64(8), np.int64(9), np.int64(3), np.int64(7), np.int64(4), np.int64(0), np.int64(4), np.int64(3), np.int64(0), np.int64(7), np.int64(0), np.int64(3), np.int64(9), np.int64(1), np.int64(7), np.int64(
# ...

# %%
conf_matrix=confusion_matrix(Y_test,Y_pred_labels)
print(conf_matrix)
# Out:
# tf.Tensor(
# [[ 959    1    1    3    1    4    4    2    4    1]
#  [   4 1106    0    4    5    1    3    2    8    2]
#  [  14   31  911   23    1    4    3   15   28    2]
#  [   1   13   39  917    0   14    2    6   15    3]
#  [  20    0   14    0  924    0    4    0    1   19]
#  [   3    4    2   32    4  819    8    1   16    3]
#  [ 693    3    4    0   20   15  214    0    9    0]
#  [   2    6    9   18    3    1    0  976    0   13]
#  [  19    0    4   14   10   16    5    1  888   17]
#  [  10    3    0    4   65    7    0    5    8  907]], shape=(10, 10), dtype=int32)

# %%
plt.figure(figsize=(15,7))
sns.heatmap(conf_matrix,annot=True,fmt='d',cmap='Blues')
plt.ylabel('True Labels')
plt.xlabel('Predicted Labels')
# Out:
# Text(0.5, 47.7222222222222, 'Predicted Labels')

# %%
input_image _path=("path of image")
input_image=cv2.imread(input_image_path)
cv2_imshow(input_image)
grayscale=cv2.cvtColor(input_image,cv2.COLOR_RGB2GRAY)
input_image_resize=cv2.resize(grayscale,(28,28))
input_image_resize=input_image_resize/255
input_image_reshape=input_image_resize.reshape(1,28,28)
prediction=model.predict(input_image_reshape)
print(prediction)
prediction_label=np.argmax(prediction)
print(prediction_label)
